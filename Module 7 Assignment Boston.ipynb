# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
boston_df=pd.read_csv(boston_url)

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %% [markdown]
# # Task 1: Become familiar with the Dataset

# %%
#CRIM - per capita crime rate by town
#ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#INDUS - proportion of non-retail business acres per town.
#CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#NOX - nitric oxides concentration (parts per 10 million)
#RM - average number of rooms per dwelling
#AGE - proportion of owner-occupied units built prior to 1940
#DIS - weighted distances to five Boston employment centres
#RAD - index of accessibility to radial highways
#TAX - full-value property-tax rate per $10,000
#PTRATIO - pupil-teacher ratio by town
#LSTAT - % lower status of the population
#MEDV - Median value of owner-occupied homes in $1000's

# %%
#Data Frame Check
boston_df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO  LSTAT  MEDV
# ...

# %%
#Dataframe information
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  LSTAT       506 non-null    float64
#  13  MEDV        506 non-null    float64
#  14  River       506 non-null    object
#  15  age_group   506 non-null    object
# dtypes: float64(13), int64(1), object(2)
# memory usage: 59.4+ KB

# %%
#Dataframe Detailed Analysis
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# # Task 2: Generate Descriptive Statistics and Visualizations

# %% [markdown]
# ### For the "Median value of owner-occupied homes" provide a boxplot

# %%
# For the "Median value of owner-occupied homes" provide a boxplot
bp = sns.boxplot(y = 'MEDV', data = boston_df)
bp.set_title('Median Value of owner-occupied homes')
# Out:
# Text(0.5, 1.0, 'Median Value of owner-occupied homes')

# %% [markdown]
# ### Provide a  bar plot for the Charles river variable

# %%
# Provide a  bar plot for the Charles river variable

bc = sns.countplot(x ='CHAS', hue = 'CHAS', data = boston_df)
bc.bar_label(bc.containers[0], label_type='edge')
bc.set_title('Charles River Variable')
# Out:
# Text(0.5, 1.0, 'Charles River Variable')

# %% [markdown]
# Small amount of properties are near the river

# %% [markdown]
# ### Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)

# %%
# Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)

# Generate Age Ranges
boston_df.loc[(boston_df['AGE'] <= 35), 'Age_Group'] = '35 years and younger '
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'Age_Group'] = 'Between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'Age_Group'] = '+ 70 years '

# Boxplot2
bp2 = sns.boxplot(x = 'MEDV', y = 'Age_Group', hue='Age_Group',  data = boston_df)
bp2.set_title('Median value of owner-occupied homes per Age Group')
# Out:
# Text(0.5, 1.0, 'Median value of owner-occupied homes per Age Group')

# %% [markdown]
# ### Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?

# %%
# Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?
sp = sns.scatterplot(y = 'INDUS', x = 'NOX', data = boston_df)
sp.set_title('Nitric oxide concentration per proportion of non-retail business acres per town')
# Out:
# Text(0.5, 1.0, 'Nitric oxide concentration per proportion of non-retail business acres per town')

# %% [markdown]
# **FINDING: Nox concentrations flatten out at 0.6 parts per 10 million**

# %% [markdown]
# ### Create a histogram for the pupil to teacher ratio variable

# %%
#Create a histogram for the pupil to teacher ratio variable
pyplot.figure(figsize=(10,5))
sns.histplot(
    boston_df.PTRATIO,bins=10, kde=True)
pyplot.title("Histogram for the pupil to teacher ratio variable")
pyplot.show()

# %% [markdown]
# # Task 3: Use the appropriate tests to answer the questions provided.

# %% [markdown]
# ### Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

# %% [markdown]
# **HYPOTHESIS**
# - Null Hypothesis = No difference in median value of houses
# - Alternative Hypothesis = Statistical difference in median value of houses near the Charles River

# %%
#Boston Dataframe CHAS value counts
boston_df["CHAS"].value_counts()
# Out:
# CHAS
# 0.0    471
# 1.0     35
# Name: count, dtype: int64

# %%
# Identifies Median value of all properties with CHAS Value of 0 (Not Near River)
a = boston_df[boston_df["CHAS"] == 0]["MEDV"]
a
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 471, dtype: float64

# %%
# Identifies Median value of all properties with CHAS Value of 1 (Near River) 
b = boston_df[boston_df["CHAS"] == 1]["MEDV"]
b
# Out:
# 142    13.4
# 152    15.3
# 154    17.0
# 155    15.6
# 160    27.0
# 162    50.0
# 163    50.0
# 208    24.4
# 209    20.0
# 210    21.7
# 211    19.3
# 212    22.4
# 216    23.3
# 218    21.5
# 219    23.0
# 220    26.7
# 221    21.7
# 222    27.5
# 234    29.0
# 236    25.1
# 269    20.7
# 273    35.2
# 274    32.4
# 276    33.2
# 277    33.1
# 282    46.0
# 283    50.0
# 356    17.8
# 357    21.7
# 358    22.7
# 363    16.8
# 364    21.9
# 369    50.0
# 370    50.0
# 372    50.0
# Name: MEDV, dtype: float64

# %%
scipy.stats.ttest_ind(a,b,axis=0,equal_var=True)
# Out:
# TtestResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05, df=504.0)

# %% [markdown]
# **FINDING: pvalue is greater than 0.05. Fail to reject the null hypothesis since there is NO statistical significance.**

# %% [markdown]
# ### Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %% [markdown]
# **HYPOTHESIS**
# - Null Hypothesis = No difference in Median Value of houses built prior to 1940
# - Alternative Hypothesis = Statistical difference in Median value of houses built prioer to 1940

# %%
#Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# **FINDING: There is a statistical difference in the median vlaue of houses**

# %% [markdown]
# ### Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %% [markdown]
# **HYPOTHESIS**
# - Null Hypothesis = Nitric Oxide concentration is not related to non-retail acerage
# - Alternative Hypothesis = There is a relationship between Nitric Oxide concentration and non-retail acerage

# %%
#Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)
pearson,p_value = scipy.stats.pearsonr(boston_df["NOX"],boston_df["INDUS"])
print("Pearson Coefficient value={0}, P-value={1}".format(pearson,p_value))
# Out:
# Pearson Coefficient value=0.7636514469209192, P-value=7.913361061210442e-98

# %% [markdown]
# **FINDING: There is a relationship between Nitric Oxide and non-business acreage per town**

# %% [markdown]
# ### What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %% [markdown]
# **HYPOTHESIS**
# - Null Hypothesis = Weighted distance to employment centres are not related to median home values
# - Alternative Hypothesis = Weighted distance to employment centres do impact median home values

# %%
#What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)
x = boston_df['DIS']
y = boston_df['MEDV']

x = sm.add_constant(x)

analysis = sm.OLS(y, x).fit()
predisction = model.predict(x)

analysis.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Sat, 14 Dec 2024   Prob (F-statistic):           1.21e-08
# Time:                        22:20:13   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %%
np.sqrt(0.061)
# Out:
# 0.2469817807045694

# %%
boston_df.corr()
# Out:
#             Unnamed: 0      CRIM        ZN     INDUS      CHAS       NOX  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# CRIM          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# ZN           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# INDUS         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# CHAS         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# NOX           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# RM           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# AGE           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# DIS          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# RAD           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# TAX           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# PTRATIO       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %% [markdown]
# **FINDING: There is a impact of weighted distance between the employment centres and median value of owner occuppied homes**
